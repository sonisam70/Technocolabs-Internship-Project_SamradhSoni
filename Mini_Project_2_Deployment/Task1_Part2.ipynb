# %%
import pandas as pd
import numpy as np

df = pd.read_csv('cleaned_data1.csv')

# %%
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24      2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2  85698822-43f5      90000    2          2         2   34      0      0
# 3  0737c11b-be42      50000    2          2         1   37      0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57     -1      0
#
#    PAY_3  PAY_4  ...  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0     -1     -1  ...         0         0         0         0
# 1      0      0  ...      1000      1000         0      2000
# 2      0      0  ...      1000      1000      1000      5000
# 3      0      0  ...      1200      1100      1069      1000
# 4     -1      0  ...     10000      9000       689       679
#
#    default payment next month  EDUCATION_CAT  graduate school  high school  \
# 0                           1     university                0            0
# 1                           1     university                0            0
# 2                           0     university                0            0
# 3                           0     university                0            0
# 4                           0     university                0            0
#
#    others  university
# 0       0           1
# 1       0           1
# 2       0           1
# 3       0           1
# 4       0           1
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (26664, 30)

# %%
df.describe()
# Out:
#            LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count   26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean   167919.054905      1.603060      1.842334      1.556031     35.505213
# std    129839.453081      0.489272      0.744661      0.521463      9.227442
# min     10000.000000      1.000000      1.000000      1.000000     21.000000
# 25%     50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%    140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%    240000.000000      2.000000      2.000000      2.000000     41.000000
# max    800000.000000      2.000000      4.000000      3.000000     79.000000
#
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# std        1.126769      1.198640      1.199165      1.167897      1.131735
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  ...  2.666400e+04   26664.000000   26664.000000   26664.000000
# mean   ...  5.881110e+03    5259.514964    4887.048717    4843.729973
# std    ...  2.121431e+04   17265.439561   15956.349371   15311.721795
# min    ...  0.000000e+00       0.000000       0.000000       0.000000
# 25%    ...  8.020000e+02     390.000000     294.750000     242.750000
# 50%    ...  2.007000e+03    1822.000000    1500.000000    1500.000000
# 75%    ...  5.000000e+03    4556.250000    4050.500000    4082.750000
# max    ...  1.227082e+06  889043.000000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month  graduate school  \
# count   26664.000000                26664.000000     26664.000000
# mean     5257.843047                    0.221797         0.352985
# std     17635.468185                    0.415463         0.477907
# min         0.000000                    0.000000         0.000000
# 25%       111.000000                    0.000000         0.000000
# 50%      1500.000000                    0.000000         0.000000
# 75%      4015.000000                    0.000000         1.000000
# max    528666.000000                    1.000000         1.000000
#
#         high school        others    university
# count  26664.000000  26664.000000  26664.000000
# mean       0.164266      0.015527      0.467222
# std        0.370524      0.123637      0.498934
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000
#
# [8 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'EDUCATION_CAT', 'graduate school',
#        'high school', 'others', 'university'],
#       dtype='object')

# %%
pay_feats = ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']

# %%
df[pay_feats].describe()
# Out:
#               PAY_1         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  26664.000000  26664.000000  26664.000000  26664.000000  26664.000000
# mean      -0.017777     -0.133363     -0.167679     -0.225023     -0.269764
# std        1.126769      1.198640      1.199165      1.167897      1.131735
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_6
# count  26664.000000
# mean      -0.293579
# std        1.150229
# min       -2.000000
# 25%       -1.000000
# 50%        0.000000
# 75%        0.000000
# max        8.000000

# %%
df[pay_feats[0]].value_counts().sort_index()
# Out:
# -2     2476
# -1     5047
#  0    13087
#  1     3261
#  2     2378
#  3      292
#  4       63
#  5       23
#  6       11
#  7        9
#  8       17
# Name: PAY_1, dtype: int64

# %%
df[pay_feats[0]].hist()

# %%
pay_1_bins = np.array(range(-2,10)) - 0.5
pay_1_bins
# Out:
# array([-2.5, -1.5, -0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,
#         8.5])

# %%
import matplotlib.pyplot as plt
df[pay_feats[0]].hist(bins=pay_1_bins)
plt.xlabel('PAY_1')
plt.ylabel('Number of accounts')
# Out:
# Text(0, 0.5, 'Number of accounts')

# %%
import matplotlib as mpl
mpl.rcParams['font.size'] = 6
df[pay_feats].hist(bins=pay_1_bins, layout=(2,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002B1D87E4790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B1D870AFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B1D7D48FD0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002B1D8691460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B1D8B89B50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002B1D8BB6040>]],
#       dtype=object)

# %%
df.loc[df['PAY_2']==2, ['PAY_2', 'PAY_3']].head()
# Out:
#     PAY_2  PAY_3
# 0       2     -1
# 1       2      0
# 13      2      2
# 15      2      0
# 47      2      2
